# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Josien</b>
# Neuroscientist

# %% [markdown]
# _I am interested in data science, because I want to learn more about programming and statistics_

# %% [markdown]
# <h3> The code will wish you a Merry Christmas</h3>

# %%
print("Merry Christmas")
# Out:
# Merry Christmas

# %% [markdown]
# 1. <strike>2021</strike>
# 2. <strike>2022</strike>
# 3. 2023
# ![happy-new-year-2023.jpg](attachment:db08b274-2e2b-4278-bdd9-f5ab9af2e9d0.jpg)
